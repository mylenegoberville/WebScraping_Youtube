# %%
# Création du dossier WebCrawler contenant l'ensemble des fichiers utiles au fonctionnement de scrapy
# !scrapy startproject WebCrawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\kody\WebCrawler

# %%
# Création du projet Youtube dans le dossier WebCrawler/spider
# !cd WebCrawler && scrapy genspider wallhaven https://wallhaven.cc/user/JustJon
# Out:
# Spider 'wallhaven' already exists in module:
#   WebCrawler.spiders.wallhaven

# %%
#À ajouter au fichier items.py
class ReviewsWallhavenItem(scrapy.Item):
    user_name = scrapy.Field()
    last_active = scrapy.Field()
    joined = scrapy.Field()
    uploads = scrapy.Field()
    views = scrapy.Field()
    favorites = scrapy.Field()
    subscribe = scrapy.Field()
    comments = scrapy.Field()
    posts = scrapy.Field()
    wallpapers_tagged = scrapy.Field()
    Wallpapers_flagged = scrapy.Field()

# %%
response.css('dl.datalist')

# %%
import scrapy
from scrapy import Request
from WebCrawler.items import ReviewsWallhavenItem
import time

class WallhavenSpider(scrapy.Spider):
    name = 'wallhaven'
    allowed_domains = ['wallhaven.cc']
    
    #Pas encore automatiser mais en changeant l'url manuellement on peut obtenir plusieurs utilisateurs dans le CSV
    #start_urls = ['https://wallhaven.cc/user/JustJon']
    start_urls = ['https://wallhaven.cc/user/jofire']

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_wallhaven)
            
    def parse_wallhaven(self, response):
        item = ReviewsWallhavenItem()
        liste_items = response.css('dd')
        
        #user name
        try: 
            item['user_name'] = response.css('h1.username').css('a::text').extract()
        except:
            item['user_name'] = 'None'
        
        #last active
        try: 
            item['last_active'] = liste_items[0].css('time::text').extract()
        except:
            item['last_active'] = 'None'

        #years of inscription
        try: 
            item['joined'] = liste_items[1].css('time::text').extract()
        except:
            item['joined'] = 'None'

        #number of upload
        try: 
            item['uploads'] = liste_items[2].css('::text').extract()
        except:
            item['uploads'] = 'None'

        #number of views
        try: 
            item['views'] = liste_items[3].css('::text').extract()
        except:
            item['views'] = 'None'

        #favorites wallpaper
        try: 
            item['favorites'] = liste_items[4].css('::text').extract()
        except:
            item['favorites'] = 'None'

        #number of subscribers
        try: 
            item['subscribe'] = liste_items[5].css('::text').extract()
        except:
            item['subscribe'] = 'None'

        #number of comments
        try: 
            item['comments'] = liste_items[6].css('::text').extract()
        except:
            item['comments'] = 'None'

        #number of posts
        try: 
            item['posts'] = liste_items[7].css('::text').extract()
        except:
            item['posts'] = 'None'

        #number of wallpaper tagged
        try: 
            item['wallpapers_tagged'] = liste_items[8].css('::text').extract()
        except:
            item['wallpapers_tagged'] = 'None'

        #number of wallpaper flagged
        try: 
            item['Wallpapers_flagged'] = liste_items[9].css('::text').extract()
        except:
            item['Wallpapers_flagged'] = 'None'

        yield item

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl wallhaven -o wallhaven.csv
# Out:
# 2022-10-20 17:18:42 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: WebCrawler)
# 2022-10-20 17:18:42 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.0, Platform Windows-10-10.0.19043-SP0
# 2022-10-20 17:18:42 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders']}
# 2022-10-20 17:18:42 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-10-20 17:18:42 [scrapy.extensions.telnet] INFO: Telnet Password: b673c826c0058902
# 2022-10-20 17:18:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-20 17:18:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-20 17:18:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-20 17:18:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-20 17:18:42 [scrapy.core.engine] INFO: Spider opened
# 2022-10-20 17:18:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-20 17:18:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2022-10-20 17:18:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://wallhaven.cc/robots.txt> (referer: None)
# 2022-10-20 17:18:45 [filelock] DEBUG: Attempting to acquire lock 1353197647568 on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Lock 1353197647568 acquired on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Attempting to acquire lock 1353197648960 on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Lock 1353197648960 acquired on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Attempting to release lock 1353197648960 on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Lock 1353197648960 released on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Attempting to release lock 1353197647568 on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-20 17:18:45 [filelock] DEBUG: Lock 1353197647568 released on C:\Users\kody\.cache\python-tldextract\3.9.12.final__miniconda3__0e2542__tldextract-3.2.0\publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-20 17:18:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://wallhaven.cc/user/jofire> (referer: None)
# 2022-10-20 17:18:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://wallhaven.cc/user/jofire>
#
# {'Wallpapers_flagged': ['2'],
#  'comments': ['55'],
#  'favorites': ['331'],
#  'joined': ['1 year ago'],
#  'last_active': ['10 minutes ago'],
#  'posts': ['1'],
#  'subscribe': ['17,245'],
#  'uploads': ['421'],
#  'user_name': ['jofire'],
#  'views': ['55'],
#  'wallpapers_tagged': ['472']}
# 2022-10-20 17:18:45 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-20 17:18:45 [scrapy.extensions.feedexport] INFO: Stored csv feed (1 items) in: wallhaven.csv
# 2022-10-20 17:18:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 453,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 11148,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 2.777041,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 20, 15, 18, 45, 594211),
#  'httpcompression/response_bytes': 51082,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 12,
#  'log_count/INFO': 11,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 10, 20, 15, 18, 42, 817170)}
# 2022-10-20 17:18:45 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

pd.read_csv('./WebCrawler/WebCrawler/spiders/wallhaven.csv')
# Out:
#    Wallpapers_flagged  comments  favorites       joined     last_active  \
# 0                   1        38        579  8 years ago     4 hours ago
# 1  Wallpapers_flagged  comments  favorites       joined     last_active
# 2                   1        38        579  8 years ago     4 hours ago
# 3  Wallpapers_flagged  comments  favorites       joined     last_active
# 4                   0         0          1  8 years ago   3 minutes ago
# 5  Wallpapers_flagged  comments  favorites       joined     last_active
# 6                   2        55        331   1 year ago  10 minutes ago
#
#    posts  subscribe  uploads  user_name  views  wallpapers_tagged
# 0     28     36,021      943    JustJon  1,179              1,013
# 1  posts  subscribe  uploads  user_name  views  wallpapers_tagged
# 2     28     36,021      942    JustJon  1,179              1,013
# 3  posts  subscribe  uploads  user_name  views  wallpapers_tagged
# 4      0        939        4     ArtMan    786                 13
# 5  posts  subscribe  uploads  user_name  views  wallpapers_tagged
# 6      1     17,245      421     jofire     55                472
